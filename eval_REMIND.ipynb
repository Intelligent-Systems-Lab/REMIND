# %% [markdown]
# Load datasets and generate result

# %%
from datetime import datetime, timedelta
import re

def transform_time_intervals(intervals):
    def parse_relative_time(text):
        match = re.match(r"A (few|couple of) (hours|days|weeks|months|years) after", text)
        if match:
            qty = 3 if match.group(1) == "few" else 2
            unit = match.group(2)
            delta = {
                "hours": timedelta(hours=qty),
                "days": timedelta(days=qty),
                "weeks": timedelta(weeks=qty),
                "months": timedelta(days=qty * 30),  # Approximate month as 30 days
                "years": timedelta(days=qty * 365)  # Approximate year as 365 days
            }
            return delta[unit]
        return None

    def generate_timeline(events):
        now = datetime.now() - timedelta(minutes=10)  # 固定當前時間
        timeline = [now]
        for event in reversed(events[1:]):
            delta = parse_relative_time(event)
            if delta:
                now -= delta
            timeline.append(now)

        return list(reversed(timeline))
    
    result = generate_timeline(intervals)
    if len([dt.strftime("%Y-%m-%d %H:%M") for dt in result]) > 5:
        print(f'error:{intervals}')
    return [dt.strftime("%Y-%m-%d %H:%M") for dt in result]

# %%
import pandas as pd
question_df = pd.read_json('questions_0205.json', lines=True)
question_df['time_changed'] = question_df['time_interval'].apply(transform_time_intervals)
question_df = question_df.drop(['check', 'evidence', 'explain', 'answer', 'generate_dialogue', 'relationship', 'time_interval'], axis=1)

# %%
import pandas as pd
question_df = pd.read_json("eval_result_remind.json", lines=True)

# %%
question_df.head()
# Out:
#           dataID                             first_session_dialogue  \
# 0  episode-15761  [Hi there, how are you doing today?, Hi. I'm d...
# 1  episode-15776  [Hey, B. Can I talk to you about something per...
# 2  episode-15784  [I'm so sick of having to take out the trash e...
# 3  episode-15787  [Hey there, Classmates B! What's up? Why are y...
# 4  episode-15790  [Hey, how's your day going so far?, It's going...
#
#                               first_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                              second_session_dialogue  \
# 0  [That looks like an interesting book, do you m...
# 1  [Hey, I have some exciting news to share with ...
# 2  [Today's hike was so much fun! I loved explori...
# 3  [Hey, have you ever witnessed a car accident?,...
# 4  [Hey., Hey, everything okay?, Yeah, everything...
#
#                              second_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                               third_session_dialogue  \
# 0  [Hey there, did you see me riding my bike in t...
# 1  [Hey, did I tell you about my bike ride to the...
# 2  [ I'm just so sick of taking out the trash eve...
# 3  [I'm almost done with my work for today. Just ...
# 4  [I can't stop thinking about the Grand Canyon....
#
#                               third_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Parent,...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                              fourth_session_dialogue  \
# 0  [It's nice to be back in the neighborhood afte...
# 1  [I moved in with my grandparents when I was ju...
# 2  [Today was amazing, I won the contest and I fe...
# 3  [You know, I still get emotional thinking abou...
# 4  [I don't know where the chips went. I put them...
#
#                              fourth_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                               fifth_session_dialogue  \
# 0  [Ugh, my boss keeps calling me on my days off....
# 1  [I just can't believe my grandson is gone. I f...
# 2  [When I was ten, I moved in with my grandparen...
# 3  [Hey, what are you reading there?, Just a book...
# 4  [Hey, have you seen the book I was looking at ...
#
#                               fifth_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                                         time_changed question_type  \
# 0  [2021-01-11 09:18, 2021-04-11 09:18, 2021-04-1...          long
# 1  [2023-01-05 12:18, 2025-01-04 12:18, 2025-01-0...           mix
# 2  [2019-04-09 12:18, 2021-04-08 12:18, 2021-04-1...          long
# 3  [2023-04-02 12:18, 2023-04-05 12:18, 2023-04-0...         short
# 4  [2024-07-11 12:18, 2024-10-09 12:18, 2025-01-0...          long
#
#                                             question
# 0  Remember when I said you could borrow somethin...
# 1  Do you remember what personal change I mention...
# 2  Remember our hike today? What specifically did...
# 3  Remember when you mentioned the book you're re...
# 4  Remember when you were really stressed about o...

# %%
question_df = question_df[question_df['question_type']=='short']
len(question_df)
# Out:
# 169

# %%
question_df.reset_index(drop=True, inplace=True)
question_df.head()
# Out:
#           dataID                             first_session_dialogue  \
# 0  episode-15787  [Hey there, Classmates B! What's up? Why are y...
# 1  episode-15880  [I was thinking about doing something special ...
# 2  episode-15899  [Hey, have you heard about the new project we'...
# 3  episode-15958  [Hey, how's it going?, Not bad, thanks. How ab...
# 4  episode-15977  [Hey, Neighbors B! How are you doing today?, I...
#
#                               first_session_speakers  \
# 0  [Classmates A, Classmates B, Classmates A, Cla...
# 1  [Parent, Child, Parent, Child, Parent, Child, ...
# 2  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 3  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 4  [Neighbors A, Neighbors B, Neighbors A, Neighb...
#
#                              second_session_dialogue  \
# 0  [Hey, have you ever witnessed a car accident?,...
# 1  [Child, I want to talk to you about something ...
# 2  [So yeah, I'm really excited about becoming a ...
# 3  [Excuse me, I was wondering if you could help ...
# 4  [I finally got around to mowing the lawn yeste...
#
#                              second_session_speakers  \
# 0  [Classmates A, Classmates B, Classmates A, Cla...
# 1  [Parent, Child, Parent, Child, Parent, Child, ...
# 2  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 3  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 4  [Neighbors A, Neighbors B, Neighbors A, Neighb...
#
#                               third_session_dialogue  \
# 0  [I'm almost done with my work for today. Just ...
# 1  [Guess what, kiddo? I got a new car!, That's g...
# 2  [, you wouldn't believe what I did over the we...
# 3  [I hope it doesn't rain today., Why is that?, ...
# 4  [It's crazy to think that I've been living wit...
#
#                               third_session_speakers  \
# 0  [Classmates A, Classmates B, Classmates A, Cla...
# 1  [Parent, Child, Parent, Child, Parent, Child, ...
# 2  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 3  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 4  [Neighbors A, Neighbors B, Neighbors A, Neighb...
#
#                              fourth_session_dialogue  \
# 0  [You know, I still get emotional thinking abou...
# 1  [You know, jumping on the trampoline made me f...
# 2  [Hey, that looks like an interesting book you'...
# 3  [I'm really grateful that I have this job at t...
# 4  [Hi there, Neighbors B! How are you doing toda...
#
#                              fourth_session_speakers  \
# 0  [Classmates A, Classmates B, Classmates A, Cla...
# 1  [Parent, Child, Parent, Child, Parent, Child, ...
# 2  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 3  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 4  [Neighbors A, Neighbors B, Neighbors A, Neighb...
#
#                               fifth_session_dialogue  \
# 0  [Hey, what are you reading there?, Just a book...
# 1  [ I can't believe my grandson is gone. It's so...
# 2  [That story reminds me of when I learned how t...
# 3  [I had a bike with two wheels and a bell, and ...
# 4  [My grandson passed away last month, and I sti...
#
#                               fifth_session_speakers  \
# 0  [Classmates A, Classmates B, Classmates A, Cla...
# 1  [Parent, Child, Parent, Child, Parent, Child, ...
# 2  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 3  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 4  [Neighbors A, Neighbors B, Neighbors A, Neighb...
#
#                                         time_changed question_type  \
# 0  [2023-04-02 12:18, 2023-04-05 12:18, 2023-04-0...         short
# 1  [2025-02-24 09:18, 2025-02-24 12:18, 2025-03-1...         short
# 2  [2023-02-28 09:18, 2023-03-21 09:18, 2025-03-2...         short
# 3  [2024-10-12 06:18, 2024-10-12 09:18, 2025-01-1...         short
# 4  [2021-02-28 12:18, 2021-03-21 12:18, 2023-03-2...         short
#
#                                             question
# 0  Remember when you mentioned the book you're re...
# 1  Remember when we talked about keeping his memo...
# 2  Remember when we talked about biking? What out...
# 3  Remember when I mentioned how satisfying it is...
# 4  Do you remember saying that losing a loved one...

# %%
from long_memory.component import WeaviateLongMemory
from short_memory.component import WeaviateShortMemory

long_mem = WeaviateLongMemory(user='GPT_4o_mini')
short_mem = WeaviateShortMemory(user='GPT_4o_mini')
# Out:
# Detect existed GPT_4o_mini user group memory space, loading...
# Detect existed GPT_4o_mini user child memory space, loading...
# Detect existed GPT_4o_mini user short memory space, loading...

# %%
combine_prompt = """The following memories have been retrieved from the system.

Recent memory:{short_memory}

Older memory:{long_memory}"""

# %%
import math
from datetime import datetime, timedelta

yesterday = datetime.now() - timedelta(days=1)
for row in range(len(question_df)):
    print(f'---process {row+1}---')
    
    question = f"user:{question_df['question'][row]}"
    
    # remind process
    success = False
    while not success:
        try:
            long_mem.del_memory()
            short_mem.del_memory()
            for number, col in enumerate(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue']):
                chatlogs = []
                current_time = datetime.strptime(question_df['time_changed'][row][number], "%Y-%m-%d %H:%M")
                # save to long or short by time
                if current_time >= yesterday:
                    for i in range(math.ceil(len(question_df[col][row])/2)):
                        try:
                            chatlogs.append({
                                "user":question_df[col][row][i*2],
                                "assistant":question_df[col][row][i*2+1],
                                "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                            })
                        except:
                            chatlogs.append({
                                "user":question_df[col][row][i*2],
                                "assistant":"",
                                "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                            })
                        current_time = current_time + timedelta(minutes=1)
                    short_mem.add_chatlogs(chatlogs)
                else:
                    for i in range(math.ceil(len(question_df[col][row])/2)):
                        try:
                            chatlogs.append({
                                "text":f"user:{question_df[col][row][i*2]}, assistant:{question_df[col][row][i*2+1]}",
                                "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                            })
                        except:
                            chatlogs.append({
                                "text":f"user:{question_df[col][row][i*2]}",
                                "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                            })
                        current_time = current_time + timedelta(minutes=1)
                    long_mem.add_chat_logs(chatlogs)
            success = True
        except Exception as e:
            print(f"---remind error:{e}, retry...---")
    
    # get memory
    success = False
    while not success:
        try:
            # searched_memory
            long_memory = long_mem.get_memory(question, recall=True, retrieve_number=5)
            long_group = long_mem.get_memory(question, recall=False, retrieve_number=5)
            short_memory = short_mem.get_memory(question, k=5)
            searched_memory = combine_prompt.format(short_memory=short_memory, long_memory=long_memory)
            question_df.loc[row, 'remind_result'] = str(searched_memory)
            question_df.loc[row, 'stm_result'] = str(short_memory)
            question_df.loc[row, 'ltm_result'] = str(long_memory)
            question_df.loc[row, 'long_group'] = str(long_group)
            success = True
        except Exception as e:
            print(f"---remind error:{e}, retry...---")

    if (row+1)%50==0:
        question_df.to_json("eval_result_remind_short.json", orient="records", lines=True)
question_df.to_json("eval_result_remind_short.json", orient="records", lines=True)
# Out:
# ---process 1---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 2---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 3---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 4---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 5---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 6---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 7---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 8---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 9---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 10---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 11---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 12---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 13---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 14---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 15---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 16---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 17---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 18---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 19---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 20---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 21---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 22---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# ---remind error:Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': 'update vector: read response body: stream error: stream ID 1849; INTERNAL_ERROR; received from peer'}]}., retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 23---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 24---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 25---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 26---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 27---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 28---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 29---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 30---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 31---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 32---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 33---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 34---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 35---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 36---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 37---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 38---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 39---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 40---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 41---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# ---process 42---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 43---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 44---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 45---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 46---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 47---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 48---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# ---process 49---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# Response format error:```json
# {
#     "action": "jump",
#     "id": "previous_discussion_group_id",  // Assuming there's a relevant group (not provided in the input but inferred from context)
#     "think": "The current group discussions about math tests do not address the user's emotional struggles. I will search a different group that may contain more pertinent advice on coping mechanisms or support.",
#     "evidence": []
# }
# ```
# ---remind error:string indices must be integers, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# Response format error:```json
# {
#     "action": "jump",
#     "id": "group_id_001",  // Placeholder for the ID of a relevant group that may contain coping strategies
#     "think": "The current group did not yield relevant advice regarding the user's struggles. I will look for a group that specifically addresses coping mechanisms or support strategies.",
#     "evidence": []
# }
# ```
# ---remind error:string indices must be integers, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 50---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 51---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 52---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 53---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 54---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 55---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 56---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 57---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 58---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 59---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': 'update vector: unmarshal response body. Got: HTTP/1.1 200 OK\r\nServer: gunicorn\r\nDate: Thu, 10 Apr 2025 05:11:33 GMT\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nContent-Length: 33258\r\nOpenAI-Internal-Engine-Weight: 16\r\nOpenAI-Model: text-embedding-3-small\r\nOpenAI-Version: 2020-10-01\r\nOpenAI-Organization: user-vallktvnrupbwbzohnzrrnhm\r\nX-Request-ID: req_6b1350fb60c13dcbadad8166937ded49\r\nOpenAI-Processing-Ms: 230\r\nAccess-Control-Allow-Origin: *\r\n\r\n{\n  "object": "list",\n  "data": [\n    {\n      "object": "embedding",\n      "index": 0,\n      "embedding": [\n        -0.03446499,\n        -0.02798535,\n        -0.028055172,\n        0.014167233,\n        -0.0025380924,\n        -0.030387284,\n        -0.0064970977,\n        0.030052131,\n        -0.009014243,\n        -0.042480756,\n        0.0058407546,\n        -0.0064237826,\n        0.022748569,\n        0.014844524,\n        -0.054937307,\n        0.018992053,\n        -0.02466174,\n        0.02675645,\n        -0.041866306,\n        0.059322238,\n        0.049658634,\n        0.021826897,\n        -0.00162602,\n        -0.009544903,\n        0.04488269,\n        0.004775943,\n        -0.04658639,\n        0.041894235,\n        0.03214684,\n        -0.06524329,\n        -0.0365597,\n        -0.022050332,\n        -0.03225856,\n        -0.02075161,\n        0.012945319,\n        0.015403113,\n        0.019061876,\n        0.02322337,\n        0.04317899,\n        -0.012323887,\n        0.017623508,\n        0.009516974,\n        0.03345953,\n        0.020891258,\n        0.00057822774,\n        -0.014732806,\n        -0.04535749,\n        0.050440658,\n        -0.010082546,\n        0.014928312,\n        0.0045455243,\n        0.04703326,\n        -0.0035173702,\n        0.041950095,\n        -0.0017359924,\n        -0.02681231,\n        0.028571868,\n        0.0008134464,\n        0.028027244,\n        0.01969029,\n        0.008329971,\n        -0.0012873749,\n        0.033040587,\n        0.010494506,\n        -0.022064297,\n        -0.06580188,\n        0.0027213797,\n        0.038961638,\n        -0.031476535,\n        -0.023921609,\n        -0.041447364,\n        -0.014453511,\n        -0.041000493,\n        -0.08250371,\n        0.012959283,\n        0.016925272,\n        -0.014020604,\n        -0.02798535,\n        0.04211767,\n        -0.039743666,\n        -0.019438924,\n        0.0021942107,\n        -0.032565784,\n        -0.0047864164,\n        0.014662982,\n        -0.0069265133,\n        -0.08183341,\n        0.024354516,\n        0.0026148984,\n        -0.006783375,\n        0.012435606,\n        -0.0029500523,\n        -0.016115315,\n        -0.01907584,\n        0.04759185,\n        -0.015109854,\n        -0.0026445736,\n        -0.019997515,\n        -0.0215476,\n        0.06295307,\n        0.035386663,\n        -0.03734173,\n        -0.005212341,\n        -0.037984107,\n        0.039101284,\n        -0.03186755,\n        0.028236715,\n        -0.02054214,\n        -0.013350296,\n        -0.016366681,\n        -0.07786742,\n        -0.010522435,\n        -0.025024822,\n        0.037034504,\n        -0.021128658,\n        0.023740066,\n        -0.037676882,\n        -0.07144363,\n        -0.009635674,\n        -0.027329005,\n        -0.027775878,\n        0.056585148,\n        -0.020262845,\n        -0.04482683,\n        -0.048373878,\n        -0.018391568,\n        0.0009600762,\n        -0.031448606,\n        -0.04108428,\n        -0.024885176,\n        0.038794063,\n        -0.008797789,\n        0.030778298,\n        -0.030945875,\n        0.025290154,\n        0.027692089,\n        -0.014662982,\n        -0.024508128,\n        -0.04175459,\n        -0.004985414,\n        0.029968342,\n        -0.033152305,\n        -0.025904601,\n        0.023558525,\n        0.03276129,\n        -0.0010621934,\n        ...
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# Response format error:```json
# {
#     "action": "jump",
#     "id": "related_summary_id",  // This should correspond to a relevant group about meals or dining experiences, though it's not provided here.
#     "think": "The current group summary does not reference any meals, indicating the necessity to explore a different group that might contain discussions around meals or dining experiences.",
#     "evidence": []
# }
# ```
# ---remind error:string indices must be integers, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 60---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 61---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 62---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 63---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 64---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 65---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 66---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 67---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 68---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 69---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 70---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 71---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Query call with protocol GRPC search failed with message <AioRpcError of RPC that terminated with:
# 	status = StatusCode.DEADLINE_EXCEEDED
# 	details = "Deadline Exceeded"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Deadline Exceeded", grpc_status:4, created_time:"2025-04-10T13:20:32.166089396+08:00"}"
# >., retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 72---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 73---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 74---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 75---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 76---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 77---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 78---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{9}, unknown id:set(), retry..
# Save chat logs to long memory done.
# ---process 79---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 80---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 81---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 82---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 83---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 84---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 85---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 86---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 87---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 88---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 89---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 90---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 91---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 92---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 93---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 94---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 95---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 96---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 97---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 98---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 99---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 100---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 101---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 102---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 103---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 104---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 105---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 106---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 107---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 108---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 109---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 110---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 111---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 112---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 113---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 114---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 115---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 116---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 117---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 118---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 119---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 120---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 121---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 122---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 123---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 124---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 125---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 126---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# ---process 127---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 128---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{0}, unknown id:set(), retry..
# Save chat logs to long memory done.
# ---process 129---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 130---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 131---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 132---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 133---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 134---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 135---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 136---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 137---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Response format error:```json
# {
#     "action": "jump",
#     "id": "related_summary_id",  // Please provide the ID you want to jump to
#     "think": "The closest group did not contain information about the reprimand from the boss. Jumping to another group is likely to yield more relevant insights regarding workplace dynamics or authority figures.",
#     "evidence": []
# }
# ```
# ---remind error:string indices must be integers, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 138---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 139---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 140---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 141---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 142---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 143---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 144---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---remind error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 145---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{0}, unknown id:set(), retry..
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 146---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 147---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 148---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 149---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 150---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 151---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 152---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 153---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# ---process 154---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 155---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 156---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 157---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 158---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 159---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 160---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 161---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 162---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 163---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 164---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 165---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 166---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 167---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# ---process 168---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 169---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Detect empty short memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.

# %% [markdown]
# Score

# %%
from dotenv import load_dotenv
from openai import OpenAI
import json
import re
import os

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def llm_create(prompt):
    messages = [{"role": "user", "content": prompt}]
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    return completion.choices[0].message.content

def llm_response_handler(response:str):
    """handle llm response format, especially for llama family"""
    try:
        return json.loads(response)
    except:
        response = response.strip()
        try:
            return json.loads(re.search(r"```json(.*?)```", response, re.DOTALL).group(1).strip())
        except:
            try:
                return json.loads(re.search(r"```(.*?)```", response, re.DOTALL).group(1).strip())
            except:
                return response

# %%
generate_prompt = """You are given a question from user ask assistant, and have a memory retrieve from assistant
Pretend you are assistant and give a response.

Question:{question}

Memory:{memory}"""

judge_prompt = """Your task is to label an answer to a question as ‘CORRECT’ or ‘WRONG’.

You will be given the following data:

A question (posed by user to assistant).
A ‘gold’ (ground truth) answer.
A generated answer, which you will score as CORRECT or WRONG.
The point of the question is to ask about something assistant should know about the user based on their prior conversations. The gold answer will usually be a concise and short answer that includes the referenced topic.

Example:
Question: Do you remember what I got the last time I went to Hawaii?
Gold answer: A shell necklace

The generated answer might be much longer, but you should be generous with your grading—as long as it touches on the same topic as the gold answer, it should be counted as CORRECT.

Examples of CORRECT answers:
- Oh yeah, that was so fun! I got so much stuff there, including that shell necklace.
- I got a ton of stuff... that surfboard, the mug, the necklace, those coasters too.
- That cute necklace.

Examples of WRONG answers:
- Oh yeah, that was so fun! I got so much stuff there, including that mug.
- I got a ton of stuff... that surfboard, the mug, those coasters too.
- I’m sorry, I don’t remember what you’re talking about.

Now it’s time for the real question:
Question: {question}
Gold answer: {answer}
Generated answer: {generate_answer}

Only answer CORRECT or WRONG, no need to explain"""

# %%
import pandas as pd
question_df = pd.read_json('questions_0205.json', lines=True)
question_df = question_df[question_df['question_type']=='short']
question_df.reset_index(drop=True, inplace=True)
remind_df = pd.read_json("eval_result_remind_short.json", lines=True)
judge_df = pd.DataFrame()
# judge_df = pd.read_json("judge_remind.json", lines=True)

# %%
for row in range(len(question_df)):
    print(f'---process {row+1}---')
    
    question = f"{question_df['question'][row]}"
    answer = f"{question_df['answer'][row]}"
    
    long_searched = remind_df.loc[row, 'long_group']
    long_recall_searched = remind_df.loc[row, 'ltm_result']
    short_searched = remind_df.loc[row, 'stm_result']
    remind_searched = remind_df.loc[row, 'remind_result']
    
    judge_df.loc[row, 'long_mem_result'] = long_searched
    judge_df.loc[row, 'long_mem_answer'] = llm_create(generate_prompt.format(question=question, memory=long_searched))
    judge_df.loc[row, 'long_mem_judge'] = llm_create(judge_prompt.format(question=question, answer=answer, generate_answer=judge_df.loc[row, 'long_mem_answer']))
    judge_df.loc[row, 'long_mem_recall_result'] = long_recall_searched
    judge_df.loc[row, 'long_mem_recall_answer'] = llm_create(generate_prompt.format(question=question, memory=long_recall_searched))
    judge_df.loc[row, 'long_mem_recall_judge'] = llm_create(judge_prompt.format(question=question, answer=answer, generate_answer=judge_df.loc[row, 'long_mem_recall_answer']))
    judge_df.loc[row, 'short_mem_result'] = short_searched
    judge_df.loc[row, 'short_mem_answer'] = llm_create(generate_prompt.format(question=question, memory=short_searched))
    judge_df.loc[row, 'short_mem_judge'] = llm_create(judge_prompt.format(question=question, answer=answer, generate_answer=judge_df.loc[row, 'short_mem_answer']))
    judge_df.loc[row, 'remind_result'] = remind_searched
    judge_df.loc[row, 'remind_answer'] = llm_create(generate_prompt.format(question=question, memory=remind_searched))
    judge_df.loc[row, 'remind_judge'] = llm_create(judge_prompt.format(question=question, answer=answer, generate_answer=judge_df.loc[row, 'remind_answer']))
    
    if (row+1)%20==0:
        judge_df.to_json("judge_remind_short.json", orient="records", lines=True)
judge_df.to_json("judge_remind_short.json", orient="records", lines=True)
# Out:
# ---process 1---
# ---process 2---
# ---process 3---
# ---process 4---
# ---process 5---
# ---process 6---
# ---process 7---
# ---process 8---
# ---process 9---
# ---process 10---
# ---process 11---
# ---process 12---
# ---process 13---
# ---process 14---
# ---process 15---
# ---process 16---
# ---process 17---
# ---process 18---
# ---process 19---
# ---process 20---
# ---process 21---
# ---process 22---
# ---process 23---
# ---process 24---
# ---process 25---
# ---process 26---
# ---process 27---
# ---process 28---
# ---process 29---
# ---process 30---
# ---process 31---
# ---process 32---
# ---process 33---
# ---process 34---
# ---process 35---
# ---process 36---
# ---process 37---
# ---process 38---
# ---process 39---
# ---process 40---
# ---process 41---
# ---process 42---
# ---process 43---
# ---process 44---
# ---process 45---
# ---process 46---
# ---process 47---
# ---process 48---
# ---process 49---
# ---process 50---
# ---process 51---
# ---process 52---
# ---process 53---
# ---process 54---
# ---process 55---
# ---process 56---
# ---process 57---
# ---process 58---
# ---process 59---
# ---process 60---
# ---process 61---
# ---process 62---
# ---process 63---
# ---process 64---
# ---process 65---
# ---process 66---
# ---process 67---
# ---process 68---
# ---process 69---
# ---process 70---
# ---process 71---
# ---process 72---
# ---process 73---
# ---process 74---
# ---process 75---
# ---process 76---
# ---process 77---
# ---process 78---
# ---process 79---
# ---process 80---
# ---process 81---
# ---process 82---
# ---process 83---
# ---process 84---
# ---process 85---
# ---process 86---
# ---process 87---
# ---process 88---
# ---process 89---
# ---process 90---
# ---process 91---
# ---process 92---
# ---process 93---
# ---process 94---
# ---process 95---
# ---process 96---
# ---process 97---
# ---process 98---
# ---process 99---
# ---process 100---
# ---process 101---
# ---process 102---
# ---process 103---
# ---process 104---
# ---process 105---
# ---process 106---
# ---process 107---
# ---process 108---
# ---process 109---
# ---process 110---
# ---process 111---
# ---process 112---
# ---process 113---
# ---process 114---
# ---process 115---
# ---process 116---
# ---process 117---
# ---process 118---
# ---process 119---
# ---process 120---
# ---process 121---
# ---process 122---
# ---process 123---
# ---process 124---
# ---process 125---
# ---process 126---
# ---process 127---
# ---process 128---
# ---process 129---
# ---process 130---
# ---process 131---
# ---process 132---
# ---process 133---
# ---process 134---
# ---process 135---
# ---process 136---
# ---process 137---
# ---process 138---
# ---process 139---
# ---process 140---
# ---process 141---
# ---process 142---
# ---process 143---
# ---process 144---
# ---process 145---
# ---process 146---
# ---process 147---
# ---process 148---
# ---process 149---
# ---process 150---
# ---process 151---
# ---process 152---
# ---process 153---
# ---process 154---
# ---process 155---
# ---process 156---
# ---process 157---
# ---process 158---
# ---process 159---
# ---process 160---
# ---process 161---
# ---process 162---
# ---process 163---
# ---process 164---
# ---process 165---
# ---process 166---
# ---process 167---
# ---process 168---
# ---process 169---

# %%
print(f"short mem score:{len(judge_df[judge_df['short_mem_judge']=='CORRECT'])/len(judge_df)}")
print(f"long mem score:{len(judge_df[judge_df['long_mem_judge']=='CORRECT'])/len(judge_df)}")
print(f"long mem recall score:{len(judge_df[judge_df['long_mem_recall_judge']=='CORRECT'])/len(judge_df)}")
print(f"remind score:{len(judge_df[judge_df['remind_judge']=='CORRECT'])/len(judge_df)}")
# Out:
# short mem score:0.9822485207100592
# long mem score:0.46745562130177515
# long mem recall score:0.46153846153846156
# remind score:0.9881656804733728
