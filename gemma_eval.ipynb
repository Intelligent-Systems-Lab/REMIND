# %% [markdown]
# ### Load question

# %%
from datetime import datetime, timedelta
import re

def transform_time_intervals(intervals):
    def parse_relative_time(text):
        match = re.match(r"A (few|couple of) (hours|days|weeks|months|years) after", text)
        if match:
            qty = 3 if match.group(1) == "few" else 2
            unit = match.group(2)
            delta = {
                "hours": timedelta(hours=qty),
                "days": timedelta(days=qty),
                "weeks": timedelta(weeks=qty),
                "months": timedelta(days=qty * 30),  # Approximate month as 30 days
                "years": timedelta(days=qty * 365)  # Approximate year as 365 days
            }
            return delta[unit]
        return None

    def generate_timeline(events):
        now = datetime.now() - timedelta(minutes=10)  # 固定當前時間
        timeline = [now]
        for event in reversed(events[1:]):
            delta = parse_relative_time(event)
            if delta:
                now -= delta
            timeline.append(now)

        return list(reversed(timeline))
    
    result = generate_timeline(intervals)
    if len([dt.strftime("%Y-%m-%d %H:%M") for dt in result]) > 5:
        print(f'error:{intervals}')
    return [dt.strftime("%Y-%m-%d %H:%M") for dt in result]

# %%
import pandas as pd
question_df = pd.read_json('questions_0205.json', lines=True)
question_df['time_changed'] = question_df['time_interval'].apply(transform_time_intervals)
question_df = question_df.drop(['check', 'evidence', 'explain', 'answer', 'question_type', 'generate_dialogue', 'relationship', 'time_interval'], axis=1)

# %% [markdown]
# ### Evaluation

# %%
import pandas as pd
question_df = pd.read_json('eval_result_gemma.json', lines=True)

# %%
from long_memory.component import WeaviateLongMemory
long_mem = WeaviateLongMemory(user='Gemma', model="gemma2:27b-instruct-q4_K_M")
# Out:
# Detect existed Gemma user group memory space, loading...
# Detect existed Gemma user child memory space, loading...

# %%
file_name = "eval_result_gemma.json"

# %%
import math
from datetime import datetime, timedelta

for row in range(285, 500):
    print(f'---process {row+1}---')
    
    question = f"user:{question_df['question'][row]}"
    
    # long mem process
    class_count = 0
    success = False
    while not success and class_count<5:
        try:
            class_count+=1
            long_mem.del_memory()
            for number, col in enumerate(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue']):
                chatlogs = []
                current_time = datetime.strptime(question_df['time_changed'][row][number], "%Y-%m-%d %H:%M")
                for i in range(math.ceil(len(question_df[col][row])/2)):
                    try:
                        chatlogs.append({
                            "text":f"user:{question_df[col][row][i*2]}, assistant:{question_df[col][row][i*2+1]}",
                            "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                        })
                    except:
                        chatlogs.append({
                            "text":f"user:{question_df[col][row][i*2]}",
                            "time":current_time.strftime("%Y-%m-%dT%H:%M:%SZ")
                        })
                    current_time = current_time + timedelta(minutes=1)
                long_mem.add_chat_logs(chatlogs)
            success = True
        except Exception as e:
            print(f"---long memory chatlog classify error:{e}, retry...---")
    search_count = 0
    success = False
    while not success and search_count<5:
        try:
            search_count+=1
            searched_memory = long_mem.get_memory(question, recall=False, retrieve_number=5)
            question_df.loc[row, 'long_mem_result'] = str(searched_memory)
            # (recall)
            searched_memory = long_mem.get_memory(question, recall=True, retrieve_number=5)
            question_df.loc[row, 'long_mem_recall_result'] = str(searched_memory)
            success = True
        except Exception as e:
            print(f"---long memory action error:{e}, retry...---")
    
    if (row+1)%50==0:
        question_df.to_json(file_name, orient="records", lines=True)
question_df.to_json(file_name, orient="records", lines=True)
# Out:
# ---process 286---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{5}, unknown id:set(), retry..
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{5}, unknown id:set(), retry..
# Chat logs not correct, missing id:{5}, unknown id:set(), retry..
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---long memory action error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---long memory action error:Not valid 'uuid' or 'uuid' can not be extracted from value, retry...---
# ---process 287---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 288---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 289---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 290---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 291---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 292---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 293---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 294---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 295---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 296---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 297---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 298---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 299---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 300---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 301---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory action error:'think', retry...---
# ---long memory action error:'think', retry...---
# ---long memory action error:'think', retry...---
# ---long memory action error:'think', retry...---
# ---long memory action error:'think', retry...---
# ---process 302---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 303---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 304---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 305---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 306---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 307---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 308---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 309---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 310---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 311---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 312---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 313---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 314---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 315---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 316---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 317---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 318---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 319---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 320---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 321---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 322---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 323---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 324---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 325---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 326---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 327---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory action error:'think', retry...---
# ---process 328---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 329---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 330---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 331---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 332---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:list index out of range, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 333---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 334---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 335---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 336---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 337---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 338---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 339---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 340---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 341---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 342---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 343---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 344---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 345---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 346---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 347---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 348---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{6}, unknown id:set(), retry..
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 349---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 350---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 351---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 352---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 353---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:list indices must be integers or slices, not str, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:Object was not added! Unexpected status code: 500, with response body: {'error': [{'message': 'update vector: send POST request: Post "https://api.openai.com/v1/embeddings": context deadline exceeded (Client.Timeout exceeded while awaiting headers)'}]}., retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 354---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 355---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 356---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 357---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:'NoneType' object is not iterable, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 358---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 359---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 360---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 361---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 362---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 363---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 364---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 365---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 366---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 367---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory action error:'think', retry...---
# ---process 368---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 369---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 370---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 371---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 372---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 373---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 374---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 375---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 376---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 377---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 378---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 379---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 380---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 381---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{3}, unknown id:set(), retry..
# Save chat logs to long memory done.
# ---long memory action error:'think', retry...---
# ---long memory action error:'think', retry...---
# ---process 382---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 383---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 384---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 385---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 386---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 387---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 388---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 389---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 390---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 391---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 392---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 393---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 394---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 395---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 396---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 397---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 398---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:'NoneType' object is not iterable, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 452---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 453---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 454---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 455---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 456---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 457---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{4}, unknown id:set(), retry..
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 458---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 459---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 460---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 461---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 462---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 463---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 464---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 465---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 466---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 467---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 468---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 469---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 470---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 471---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 472---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 473---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 474---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 475---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 476---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 477---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory action error:'think', retry...---
# ---process 478---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 479---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 480---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 481---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 482---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 483---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 484---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 485---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 486---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 487---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 488---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 489---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 490---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 491---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 492---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 493---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 494---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 495---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 496---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Chat logs not correct, missing id:{4}, unknown id:set(), retry..
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 497---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# ---long memory chatlog classify error:string indices must be integers, retry...---
# ---process 498---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 499---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# ---process 500---
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.
# Save chat logs to long memory done.

# %% [markdown]
# Evaluation

# %%
import pandas as pd
gemma_df = pd.read_json(file_name, lines=True)
question_df = pd.read_json('questions_0205.json', lines=True)
base_df = pd.read_json("eval_result_base.json", lines=True)
base_score = pd.read_json('eval_result_gpt_4o_mini.json', lines=True)

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def llm_create(prompt):
    messages = [{"role": "user", "content": prompt}]
    completion = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
    )
    return completion.choices[0].message.content

# %%
import requests
import json
import re

def llm_response_handler(response:str):
    """handle llm response format, especially for llama family"""
    try:
        return json.loads(response)
    except:
        response = response.strip()
        try:
            return json.loads(re.search(r"```json(.*?)```", response, re.DOTALL).group(1).strip())
        except:
            try:
                return json.loads(re.search(r"```(.*?)```", response, re.DOTALL).group(1).strip())
            except:
                return response

# %%
evaluation_prompt = """You are a reviewer, and you are reviewing a memory retrieval system,
You are given a questions and answer.

Next, you will get the memory found by these system based on this question.
The first three are systems that have already been scored.

You must evaluate the content returned by the D and E system based on the criteria listed below, ranked in order of importance:

1. Relevance of the returned information and its ability to support generating similar responses.
2. Conciseness— the more concise and noise-free the returned content, the better.
3. Readability for humans, maintaining chronological order to preserve memory continuity.

Question:{question}

A system:{short_memory}, A score:{short_score}

B system:{base_dialog}, B score:{base_score}

C system:{base_paragraph}, C score:{base_p_score}

System need to be scored:

D system:{long_memory}

E system:{long_recall_memory}

The output format is as follows, rate each memory from 1 to 10, 1 being the worst and 10 being the best.
```json
{{
    "D":"1~10",
    "E":"1~10"
}}
```"""

# %%
def get_res(origin_conversation, question, short_searched, long_searched, long_recall_searched, base_dialog_searched, base_paragraph_searched, short_s, base_s, base_p_s):
    res = llm_create(evaluation_prompt.format(origin_conversation=origin_conversation, question=question, short_memory=short_searched, 
                                              long_memory=long_searched, long_recall_memory=long_recall_searched, base_dialog=base_dialog_searched, 
                                              base_paragraph=base_paragraph_searched, short_score=short_s, base_score=base_s, base_p_score=base_p_s))
    res_dict = llm_response_handler(res)
    # print(evaluation_prompt.format(origin_conversation=origin_conversation, question=question, short_memory=short_searched, long_memory=long_searched, long_recall_memory=long_recall_searched, base_dialog=base_dialog_searched, base_paragraph=base_paragraph_searched))
    return res_dict.get('D'), res_dict.get('E')

for row in range(500):
    print(f'---process {row+1}---')
    
    
    origin_conversation = question_df['first_session_dialogue'][row]
    qa_pair = f"user:{question_df['question'][row]}, assistant:{question_df['answer'][row]}"
    
    long_searched = gemma_df.loc[row, 'long_mem_result']
    long_recall_searched = gemma_df.loc[row, 'long_mem_recall_result']
    
    short_searched = base_df.loc[row, 'short_mem_result']
    base_dialog_searched = base_df.loc[row, 'base_dialog']
    base_paragraph_searched = base_df.loc[row, 'base_paragraph']
    
    short_s = base_score.loc[row, 'short_score']
    base_s = base_score.loc[row, 'base_dialog_score']
    base_p_s = base_score.loc[row, 'base_paragraph_score']
    
    long_score, long_recall_score= get_res(origin_conversation, qa_pair, short_searched, long_searched, long_recall_searched, base_dialog_searched, base_paragraph_searched, short_s, base_s, base_p_s)
    gemma_df.loc[row, 'long_score'] = long_score
    gemma_df.loc[row, 'long_recall_score'] = long_recall_score
    if (row+1)%50==0:
        gemma_df.to_json(file_name, orient="records", lines=True)
gemma_df.to_json(file_name, orient="records", lines=True)
# Out:
# ---process 347---

# %%
number=500
observe_df = gemma_df[:number]
print(observe_df['long_score'].astype(int).sum()/number)
print(observe_df['long_recall_score'].astype(int).sum()/number)
# Out:
# 6.91
# 6.25
