# %% [markdown]
# Datasets: Conversation Chronicles
#
# https://conversation-chronicles.github.io/

# %%
import pandas as pd

df = pd.read_json('test.jsonl', lines=True)

# %%
df.head()
# Out:
#           dataID      relationship  \
# 0  episode-15761         Neighbors
# 1  episode-15776        Co-workers
# 2  episode-15784  Parent and Child
# 3  episode-15787        Classmates
# 4  episode-15790  Husband and Wife
#
#                                        time_interval  \
# 0  [Start, A few months after, A few hours after,...
# 1  [Start, A couple of years after, A few days af...
# 2  [Start, A couple of years after, A few days af...
# 3  [Start, A few days after, A few days after, A ...
# 4  [Start, A few months after, A few months after...
#
#                                              summary  \
# 0  [Neighbors A thanks Neighbor B for carrying gr...
# 1  [Co-worker A expresses feelings of scatteredne...
# 2  [The parent expresses frustration at taking ou...
# 3  [Classmates A apologizes to Classmates B for t...
# 4  [The couple expresses gratitude for each other...
#
#                               first_session_dialogue  \
# 0  [Hi there, how are you doing today?, Hi. I'm d...
# 1  [Hey, B. Can I talk to you about something per...
# 2  [I'm so sick of having to take out the trash e...
# 3  [Hey there, Classmates B! What's up? Why are y...
# 4  [Hey, how's your day going so far?, It's going...
#
#                               first_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                              second_session_dialogue  \
# 0  [That looks like an interesting book, do you m...
# 1  [Hey, I have some exciting news to share with ...
# 2  [Today's hike was so much fun! I loved explori...
# 3  [Hey, have you ever witnessed a car accident?,...
# 4  [Hey., Hey, everything okay?, Yeah, everything...
#
#                              second_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                               third_session_dialogue  \
# 0  [Hey there, did you see me riding my bike in t...
# 1  [Hey, did I tell you about my bike ride to the...
# 2  [ I'm just so sick of taking out the trash eve...
# 3  [I'm almost done with my work for today. Just ...
# 4  [I can't stop thinking about the Grand Canyon....
#
#                               third_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Parent,...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                              fourth_session_dialogue  \
# 0  [It's nice to be back in the neighborhood afte...
# 1  [I moved in with my grandparents when I was ju...
# 2  [Today was amazing, I won the contest and I fe...
# 3  [You know, I still get emotional thinking abou...
# 4  [I don't know where the chips went. I put them...
#
#                              fourth_session_speakers  \
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...
#
#                               fifth_session_dialogue  \
# 0  [Ugh, my boss keeps calling me on my days off....
# 1  [I just can't believe my grandson is gone. I f...
# 2  [When I was ten, I moved in with my grandparen...
# 3  [Hey, what are you reading there?, Just a book...
# 4  [Hey, have you seen the book I was looking at ...
#
#                               fifth_session_speakers
# 0  [Neighbors A, Neighbors B, Neighbors A, Neighb...
# 1  [Co-workers A, Co-workers B, Co-workers A, Co-...
# 2  [Parent, Child, Parent, Child, Parent, Child, ...
# 3  [Classmates A, Classmates B, Classmates A, Cla...
# 4  [Husband, Wife, Husband, Wife, Husband, Wife, ...

# %%
from component import WeaviateLongMemory
L = WeaviateLongMemory()
# Out:
# Detect existed deafult user group memory space, loading...
# Detect existed deafult user child memory space, loading...

# %%
dialog = []
for i, log in enumerate(df['first_session_dialogue'][0]):
    charact = df['first_session_speakers'][0][i]
    dialog.append(f"{charact}:{log}")
L.add_chat_logs(f"A is assistant and B is user, {dialog}")
dialog.clear()
for i, log in enumerate(df['second_session_dialogue'][0]):
    charact = df['second_session_speakers'][0][i]
    dialog.append(f"{charact}:{log}")
L.add_chat_logs(f"A is assistant and B is user, {dialog}")
dialog.clear()
for i, log in enumerate(df['third_session_dialogue'][0]):
    charact = df['third_session_speakers'][0][i]
    dialog.append(f"{charact}:{log}")
L.add_chat_logs(f"A is assistant and B is user, {dialog}")
dialog.clear()
for i, log in enumerate(df['fourth_session_dialogue'][0]):
    charact = df['fourth_session_speakers'][0][i]
    dialog.append(f"{charact}:{log}")
L.add_chat_logs(f"A is assistant and B is user, {dialog}")
dialog.clear()
for i, log in enumerate(df['fifth_session_dialogue'][0]):
    charact = df['fifth_session_speakers'][0][i]
    dialog.append(f"{charact}:{log}")
L.add_chat_logs(f"A is assistant and B is user, {dialog}")
dialog.clear()

# %%
L.show_all_groups()
# Out:
# {'id': '0bc8355b-2d9b-46f6-838b-9fc0e2b51310', 'text': 'User expresses joy about returning to the neighborhood after living with grandparents, who have passed away, and shares fond memories.'}
# {'id': '49ecb3a7-4be1-4cde-a751-8f6c75f2f1dc', 'text': 'Assistant and user discuss a book, with user sharing that it was a spontaneous library pick. They also reflect on a previous kind deed.'}
# {'id': 'b5950585-48ca-47d2-8395-440af581ba9c', 'text': 'User expresses frustration about their boss calling on days off. User and assistant discuss setting boundaries, referencing a past situation with a roommate.'}
# {'id': 'ecb393e2-ea46-48cf-b4fd-c447874271e3', 'text': 'User and assistant discuss biking. User saw assistant biking and shares how often he rides. Assistant encourages user to try biking again, offering an extra bike for borrowing.'}
# {'id': 'f31fecf7-607e-4906-a1f2-91b94c4e1b14', 'text': 'User shares appreciation for neighborly help in carrying groceries and during a snowstorm. Assistant reciprocates kindness.'}

# %%
L.del_all_memory()
# Out:
# Detect empty group memory, create memory space...
# Detect empty child memory, create memory space...
