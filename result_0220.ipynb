# %% [markdown]
# Base

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json("eval_result_base_score.json", lines=True)

columns = ['short_score', 'base_dialog_score', 'base_paragraph_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# short_score 平均數: 7.394
# short_score 中位數: 8.0
# short_score 標準差: 1.9428751889918199
# short_score 變異數: 3.7747640000000002
# ------------
# base_dialog_score 平均數: 6.724
# base_dialog_score 中位數: 7.0
# base_dialog_score 標準差: 1.830798732793968
# base_dialog_score 變異數: 3.3518239999999997
# ------------
# base_paragraph_score 平均數: 5.722
# base_paragraph_score 中位數: 6.0
# base_paragraph_score 標準差: 1.6794987347420063
# base_paragraph_score 變異數: 2.820716
# ------------

# %% [markdown]
# GPT-4o-mini

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json("eval_result_gpt-4o-mini.json", lines=True)

columns = ['long_score', 'long_recall_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# long_score 平均數: 7.732
# long_score 中位數: 8.0
# long_score 標準差: 0.9550790543195887
# long_score 變異數: 0.9121759999999999
# ------------
# long_recall_score 平均數: 8.214
# long_recall_score 中位數: 8.0
# long_recall_score 標準差: 0.9696411707430744
# long_recall_score 變異數: 0.940204
# ------------

# %% [markdown]
# Qwen2.5:32b

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json("eval_result_qwen.json", lines=True)

columns = ['long_score', 'long_recall_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# long_score 平均數: 7.138
# long_score 中位數: 7.0
# long_score 標準差: 1.4515357384508314
# long_score 變異數: 2.1069560000000003
# ------------
# long_recall_score 平均數: 7.918
# long_recall_score 中位數: 9.0
# long_recall_score 標準差: 1.8876641650463144
# long_recall_score 變異數: 3.5632759999999997
# ------------

# %% [markdown]
# Gemma2:27b

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json("eval_result_gemma.json", lines=True)

columns = ['long_score', 'long_recall_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# long_score 平均數: 6.81
# long_score 中位數: 7.0
# long_score 標準差: 1.7291327305906854
# long_score 變異數: 2.9898999999999996
# ------------
# long_recall_score 平均數: 6.408
# long_recall_score 中位數: 7.0
# long_recall_score 標準差: 2.419408192099878
# long_recall_score 變異數: 5.853536
# ------------

# %% [markdown]
# Llama3.3:70b

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json("eval_result_llama3_3.json", lines=True)

columns = ['long_score', 'long_recall_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# long_score 平均數: 7.308
# long_score 中位數: 7.0
# long_score 標準差: 1.0359227770446984
# long_score 變異數: 1.0731359999999999
# ------------
# long_recall_score 平均數: 7.698
# long_recall_score 中位數: 8.0
# long_recall_score 標準差: 1.8018867888965722
# long_recall_score 變異數: 3.246796
# ------------

# %% [markdown]
# Deepseek-v3:671b

# %%
import numpy as np
import pandas as pd
question_df = pd.read_json('eval_result_deepseek_v3.json', lines=True)

columns = ['long_score', 'long_recall_score']
observe_df = question_df.drop(['first_session_dialogue', 'second_session_dialogue', 'third_session_dialogue', 'fourth_session_dialogue', 'fifth_session_dialogue'], axis=1)

for col in columns:
    data = observe_df[col].astype(int)
    print(f"{col} 平均數: {np.mean(data)}")
    print(f"{col} 中位數: {np.median(data)}")
    print(f"{col} 標準差: {np.std(data)}")
    print(f"{col} 變異數: {np.var(data)}")
    print("------------")
# Out:
# long_score 平均數: 7.188
# long_score 中位數: 7.0
# long_score 標準差: 1.377191344730281
# long_score 變異數: 1.896656
# ------------
# long_recall_score 平均數: 8.288
# long_recall_score 中位數: 9.0
# long_recall_score 標準差: 1.5623879159798952
# long_recall_score 變異數: 2.441056
# ------------

# %% [markdown]
# KDE

# %%
import numpy as np
import pandas as pd
base_df = pd.read_json("eval_result_base_score.json", lines=True)
gpt_df = pd.read_json("eval_result_gpt-4o-mini.json", lines=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns = ['short_score', 'base_dialog_score', 'base_paragraph_score', 'long_score', 'long_recall_score']

rows, cols = 2, 3
fig, axes = plt.subplots(rows, cols, figsize=(15, 8), sharey=True)

axes = axes.flatten()

for i, column in enumerate(columns):
    if i<=3:
        data = base_df[column].astype(int)
    else:
        data = gpt_df[column].astype(int)
    sns.kdeplot(data, color='blue', fill=True, alpha=0.3, bw_adjust=0.4, ax=axes[i])
    axes[i].set_title(f"{column} Distribution")
    axes[i].set_xlabel("Score")
    axes[i].set_ylabel("Number")

for i in range(len(columns), len(axes)):
    fig.delaxes(axes[i]) 

plt.tight_layout()
plt.show()
